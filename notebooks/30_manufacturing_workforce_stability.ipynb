# %% [markdown]
# # Checkpoint 48: Manufacturing Workforce Stability
#
# This notebook reviews the probability-weighted department and Manufacturing backfill scenario. Run `scripts/run_checkpoint48.ps1` first.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROCESSED = PROJECT_ROOT / 'data' / 'processed'

department = pd.read_csv(PROCESSED / 'workforce_stability_by_department.csv')
manufacturing_role = pd.read_csv(PROCESSED / 'manufacturing_backfill_by_role.csv')
manufacturing_summary = pd.read_csv(PROCESSED / 'manufacturing_stability_summary.csv')
validation = pd.read_csv(PROCESSED / 'workforce_stability_validation.csv')

# %%
display(manufacturing_summary.T)
display(validation)
# Out:
#                                                                     0
# as_of_date                                                 2026-06-30
# planning_horizon_months                                            12
# focus_department                                        Manufacturing
# active_workforce_employees                                       1832
# model_eligible_employees                                         1808
# protected_active_employees                                         24
# expected_departures_12m                                    229.652195
# selected_for_human_review                                         162
# expected_prevented_departures                                8.371237
# residual_expected_backfills                                221.280958
# replacement_cost_exposure_usd                         19527932.193815
# planned_intervention_spend_usd                               405000.0
# planned_avoided_cost_usd                                897919.403055
# planned_net_value_usd                                   492919.403055
# residual_vacancy_days                                    13276.857492
# residual_time_to_productivity_days                       19915.286238
# residual_training_hours                                  17702.476656
# residual_coverage_hours                                  39830.572476
# policy_name                         Budget-constrained expected value
# human_review_required                                            True
# automatic_action_permitted                                      False
#                                              check status  \
# 0                      Current as-of date is exact   PASS
# 1              Current active population is unique   PASS
# 2                      Scored population is unique   PASS
# 3           Department active headcount reconciles   PASS
# 4         Department eligible headcount reconciles   PASS
# 5            Frozen selected population reconciles   PASS
# 6   Expected departures reconcile to probabilities   PASS
# 7          Expected prevented departures reconcile   PASS
# 8             Residual backfill formula reconciles   PASS
# 9                    Intervention spend reconciles   PASS
# 10                         Avoided cost reconciles   PASS
# 11                            Net value reconciles   PASS
# 12             Operational-unit formulas reconcile   PASS
# 13                  Manufacturing focus is present   PASS
# 14             Manufacturing role totals reconcile   PASS
# 15        Residual planning values are nonnegative   PASS
# 16             No current future outcomes are used   PASS
# 17                           Policy remains frozen   PASS
# 18                   Human review remains required   PASS
# 19                    Scenario caveats are present   PASS
#
#                                              observed  \
# 0                                      ['2026-06-30']
# 1                                                   0
# 2                                                   0
# 3                                                7409
# 4                                                7305
# 5                                                 700
# 6                                                 0.0
# 7                               7.105427357601002e-15
# 8                              1.4210854715202004e-14
# 9                                                 0.0
# 10                                                0.0
# 11                              4.656612873077393e-10
# 12                              7.275957614183426e-12
# 13                                      Manufacturing
# 14  {'active': 1832, 'eligible': 1808, 'selected':...
# 15  minimum_backfills=65.030661; minimum_cost=4700...
# 16                                                 []
# 17                        frozen=True; test_once=True
# 18          human_review=True; automatic_action=False
# 19                                        All present
#
#                                           requirement  \
# 0                                      ['2026-06-30']
# 1                                                   0
# 2                                                   0
# 3                                                7409
# 4                                                7305
# 5                                                 700
# 6                                            <= 1e-06
# 7                                            <= 1e-06
# 8                                            <= 1e-06
# 9                                            <= 1e-06
# 10                                           <= 1e-06
# 11                                           <= 1e-06
# 12                                           <= 1e-06
# 13                                      Manufacturing
# 14  {'active': 1832, 'eligible': 1808, 'selected':...
# 15                                 Both minimums >= 0
# 16                                                 []
# 17                        frozen=True; test_once=True
# 18          human_review=True; automatic_action=False
# 19                                        All present
#
#                                               details
# 0   All planning outputs describe one current work...
# 1   Each active employee contributes once to workf...
# 2   Each model-eligible employee contributes one c...
# 3   Department totals include eligible and protect...
# 4   Planning probabilities cover only model-eligib...
# 5   Checkpoint 48 does not change the top-700 revi...
# 6   Expected count equals the sum of individual pr...
# 7   The planning view reuses the frozen policy eff...
# 8   Residual demand equals expected departures min...
# 9   Selected employees use the committed per-emplo...
# 10  Department values sum to the current policy sc...
# 11  Expected avoided cost minus spend matches Chec...
# 12  Backfill units use the committed base-scenario...
# 13  The business framing is anchored on manufactur...
# 14  Role-level planning must sum to the Manufactur...
# 15  The scenario cannot prevent more departures or...
# 16  Current planning uses scores and assumptions, ...
# 17  Checkpoint 48 cannot retune the tested decisio...
# 18  Workforce planning does not authorize employme...
# 19  The dashboard must not present expected counts...

# %%
department_columns = [
    'department_name',
    'active_workforce_employees',
    'expected_departures_12m',
    'expected_prevented_departures',
    'residual_expected_backfills',
    'planned_net_value_usd',
]
display(department[department_columns])
# Out:
#           department_name  active_workforce_employees  \
# 0           Manufacturing                        1832
# 1             Engineering                        1532
# 2            Supply Chain                         916
# 3  Information Technology                         745
# 4        Customer Support                         544
# 5                   Sales                         750
# 6                 Finance                         579
# 7         Human Resources                         511
#
#    expected_departures_12m  expected_prevented_departures  \
# 0               229.652195                       8.371237
# 1               165.477265                      10.646820
# 2                98.381799                       1.690802
# 3                93.742732                       7.461723
# 4                84.756575                       0.713737
# 5                84.572734                       0.971566
# 6                80.706837                       3.620799
# 7                66.588264                       1.557603
#
#    residual_expected_backfills  planned_net_value_usd
# 0                   221.280958          492919.403055
# 1                   154.830445          982912.592457
# 2                    96.690997           88558.874685
# 3                    86.281009          524741.441279
# 4                    84.042838           19450.926977
# 5                    83.601168           52168.583537
# 6                    77.086038          167943.218512
# 7                    65.030661           67520.545554

# %%
role_columns = [
    'job_title',
    'active_workforce_employees',
    'expected_departures_12m',
    'selected_for_human_review',
    'expected_prevented_departures',
    'residual_expected_backfills',
    'residual_training_hours',
    'residual_coverage_hours',
]
display(manufacturing_role[role_columns])
# Out:
#                 job_title  active_workforce_employees  \
# 0   Production Technician                         783
# 1  Manufacturing Engineer                         839
# 2   Production Supervisor                         210
#
#    expected_departures_12m  selected_for_human_review  \
# 0               107.671144                          4
# 1                97.102328                        113
# 2                24.878723                         45
#
#    expected_prevented_departures  residual_expected_backfills  \
# 0                       0.385987                   107.285157
# 1                       5.696209                    91.406119
# 2                       2.289041                    22.589682
#
#    residual_training_hours  residual_coverage_hours
# 0              8582.812587             19311.328320
# 1              7312.489496             16453.101366
# 2              1807.174574              4066.142791
